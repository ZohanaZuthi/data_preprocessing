# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
dataset=pd.read_csv("StudentPerformanceFactors.csv")

# %%
dataset.isnull().sum()
# Out:
# Hours_Studied                  0
# Attendance                     0
# Parental_Involvement           0
# Access_to_Resources            0
# Extracurricular_Activities     0
# Sleep_Hours                    0
# Previous_Scores                0
# Motivation_Level               0
# Internet_Access                0
# Tutoring_Sessions              0
# Family_Income                  0
# Teacher_Quality               78
# School_Type                    0
# Peer_Influence                 0
# Physical_Activity              0
# Learning_Disabilities          0
# Parental_Education_Level      90
# Distance_from_Home            67
# Gender                         0
# Exam_Score                     0
# dtype: int64

# %%
dataset["Teacher_Quality"].fillna(dataset["Teacher_Quality"].mode()[0],inplace=True)

# %%
dataset.isnull().sum()
# Out:
# Hours_Studied                  0
# Attendance                     0
# Parental_Involvement           0
# Access_to_Resources            0
# Extracurricular_Activities     0
# Sleep_Hours                    0
# Previous_Scores                0
# Motivation_Level               0
# Internet_Access                0
# Tutoring_Sessions              0
# Family_Income                  0
# Teacher_Quality                0
# School_Type                    0
# Peer_Influence                 0
# Physical_Activity              0
# Learning_Disabilities          0
# Parental_Education_Level      90
# Distance_from_Home            67
# Gender                         0
# Exam_Score                     0
# dtype: int64

# %%
dataset["Attendance"].value_counts()
# Out:
# Attendance
# 67     190
# 98     187
# 76     185
# 77     184
# 64     182
# 94     180
# 84     175
# 79     175
# 91     175
# 82     173
# 68     170
# 69     170
# 80     169
# 81     168
# 96     168
# 73     168
# 93     167
# 72     167
# 74     165
# 78     165
# 61     164
# 95     163
# 89     162
# 71     162
# 97     161
# 70     161
# 65     158
# 83     157
# 90     156
# 88     155
# 63     155
# 99     154
# 92     154
# 62     152
# 86     151
# 87     151
# 75     149
# 85     146
# 66     145
# 60      87
# 100     81
# Name: count, dtype: int64

# %%
dataset["Attendance"].replace("3+","3",inplace=True)

# %%
dataset["Attendance"]=dataset["Attendance"].astype("int64")

# %%
dataset.head()
# Out:
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23          84                  Low                High
# 1             19          64                  Low              Medium
# 2             24          98               Medium              Medium
# 3             29          89                  Low              Medium
# 4             19          92               Medium              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                         No            7               73              Low
# 1                         No            8               59              Low
# 2                        Yes            7               91           Medium
# 3                        Yes            8               98           Medium
# 4                        Yes            6               65           Medium
#
#   Internet_Access  Tutoring_Sessions Family_Income Teacher_Quality  \
# ...

# %% [markdown]
# To change the pattern of dataset
# when you see the outlier might hold an important data and it wont be wise to cut the outlier. then we can apply functiontransformer

# %%
from sklearn.preprocessing import FunctionTransformer
ft=FunctionTransformer(func= lambda x:x**2)
ft.fit(dataset[["Physical_Activity"]])
dataset["Physical_Activity_ft"]=ft.transform(dataset[["Physical_Activity"]])

# %%
dataset.head()
# Out:
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23          84                  Low                High
# 1             19          64                  Low              Medium
# 2             24          98               Medium              Medium
# 3             29          89                  Low              Medium
# 4             19          92               Medium              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                         No            7               73              Low
# 1                         No            8               59              Low
# 2                        Yes            7               91           Medium
# 3                        Yes            8               98           Medium
# 4                        Yes            6               65           Medium
#
#   Internet_Access  Tutoring_Sessions  ... Teacher_Quality School_Type  \
# ...
